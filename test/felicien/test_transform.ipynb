# %%
import pandas as pd
import json

json_file_path = '/Users/feliciendehertogh/Desktop/orange-competitor-analysis/data/raw_data/json/products.json'

with open(json_file_path, 'r') as f:
    data_dict = json.load(f)

df = pd.DataFrame(data_dict['products'])

df.head(1)
# Out:
#                product_name competitor_name product_category  \
# 0  mobile_prepaid_data_1_gb   mobile_viking   mobile_prepaid
#
#                                   product_url  price        date  data  \
# 0  https://mobilevikings.be/en/offer/prepaid/   10.0  2023-10-08   1.0
#
#   network  minutes  price_per_minute  sms upload_speed download_speed
# 0    None     25.0               0.4 -1.0         None           None

# %%
df['product_id'] = range(1, len(df) + 1)

# %%
df.head()
# Out:
#                   product_name competitor_name product_category  \
# 0     mobile_prepaid_data_1_gb   mobile_viking   mobile_prepaid
# 1     mobile_prepaid_data_4_gb   mobile_viking   mobile_prepaid
# 2     mobile_prepaid_data_6_gb   mobile_viking   mobile_prepaid
# 3     mobile_prepaid_data_8_gb   mobile_viking   mobile_prepaid
# 4  mobile_prepaid_voice_0.5_gb   mobile_viking   mobile_prepaid
#
#                                   product_url  price        date  data  \
# 0  https://mobilevikings.be/en/offer/prepaid/   10.0  2023-10-08   1.0
# 1  https://mobilevikings.be/en/offer/prepaid/   15.0  2023-10-08   4.0
# 2  https://mobilevikings.be/en/offer/prepaid/   20.0  2023-10-08   6.0
# 3  https://mobilevikings.be/en/offer/prepaid/   25.0  2023-10-08   8.0
# 4  https://mobilevikings.be/en/offer/prepaid/   10.0  2023-10-08   0.5
#
#   network  minutes  price_per_minute  sms upload_speed download_speed  \
# 0    None     25.0              0.40 -1.0         None           None
# 1    None     50.0              0.30 -1.0         None           None
# 2    None     67.0              0.30 -1.0         None           None
# 3    None    100.0              0.25 -1.0         None           None
# 4    None     50.0              0.20 -1.0         None           None
#
#    product_id
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
